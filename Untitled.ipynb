# %%
from faker import Faker

# %%
fake = Faker()

# %%
fake.address()
# Out:
# '075 Mason Glens\nNicoleland, IL 32847'

# %%
fake.name()
# Out:
# 'Jennifer Burton'

# %%
for i in range(0,10): 
    print(fake.name_male())
# Out:
# Robert Martinez
# John Lopez
# Scott Gonzalez
# Bryan Newton
# Peter Crosby
# Joseph Wright
# William Jones
# Jack Peterson
# Jeffrey Perez
# Michael Thomas

# %%
for i in range (0, 10000):
    transaction_id = fake.uuid4()
    event_id = fake.uuid4() 
    if transaction_id == event_id: 
        print('Hmmmm find another solution')
